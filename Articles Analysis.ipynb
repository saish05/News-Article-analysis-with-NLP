# %%
#import necessary pacakages

import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\saish\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\saish\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import re

# %%
# #read the url file into the pandas object
# df = pd.read_excel('Input.xlsx')

# #loop throgh each row in the df
# for index, row in df.iterrows():
#   url = row['URL']
#   url_id = row['URL_ID']

#   # make a request to url
#   header = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"}
#   try:
#     response = requests.get(url,headers=header)
#   except:
#     print("can't get response of {}".format(url_id))

#   #create a beautifulsoup object
#   try:
#     soup = BeautifulSoup(response.content, 'html.parser')
#   except:
#     print("can't get page of {}".format(url_id))
#   #find title
#   try:
#     title = soup.find('h1').get_text()
#   except:
#     print("can't get title of {}".format(url_id))
#     continue
#   #find text
#   article = ""
#   try:
#     for p in soup.find_all('p'):
#       article += p.get_text()
#   except:
#     print("can't get text of {}".format(url_id))

#   #write title and text to the file
#   file_name = 'C:/Users/saish/Downloads/Projects/NLP Project/Articles/' + str(url_id) + '.txt' 
#   with open(file_name, 'w',encoding='utf-8') as file:
#     file.write(title + '\n' + article)
#   print("A file has been created for "+str(url_id) )
# Out:
# can't get response of 37
# A file has been created for 37
# can't get response of 38
# A file has been created for 38
# can't get response of 39
# A file has been created for 39
# can't get response of 40
# A file has been created for 40
# can't get response of 41
# A file has been created for 41
# can't get response of 42
# A file has been created for 42
# can't get response of 43
# A file has been created for 43
# can't get response of 44
# A file has been created for 44
# can't get response of 45
# A file has been created for 45
# can't get response of 46
# A file has been created for 46
# can't get response of 47
# A file has been created for 47
# can't get response of 48
# A file has been created for 48
# can't get response of 49
# A file has been created for 49
# can't get response of 50
# A file has been created for 50
# can't get response of 51
# A file has been created for 51
# can't get response of 52
# A file has been created for 52
# can't get response of 53
# can't get page of 53
# A file has been created for 53
# can't get response of 54
# can't get page of 54
# A file has been created for 54
# can't get response of 55
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 37
#      35 #write title and text to the file
#      36 file_name = 'C:/Users/saish/Downloads/Projects/NLP Project/Articles/' + str(url_id) + '.txt'
# ---> 37 with open(file_name, 'w',encoding='utf-8') as file:
#      38   file.write(title + '\n' + article)
#      39 print("A file has been created for "+str(url_id) )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# File ~\anaconda3\lib\codecs.py:186, in IncrementalEncoder.__init__(self, errors)
#     180 class IncrementalEncoder(object):
#     181     """
#     182     An IncrementalEncoder encodes an input in multiple steps. The input can
#     183     be passed piece by piece to the encode() method. The IncrementalEncoder
#     184     remembers the state of the encoding process between calls to encode().
#     185     """
# --> 186     def __init__(self, errors='strict'):
#     187         """
#     188         Creates an IncrementalEncoder instance.
#     189
#    (...)
#     192         for a list of possible values.
#     193         """
#     194         self.errors = errors
#
# KeyboardInterrupt:

# %%
# Directories
text_dir = "C:/Users/saish/Downloads/Projects/NLP Project/Articles"
stopwords_dir = "C:/Users/saish/Downloads/Projects/NLP Project/StopWords"
sentment_dir = "C:/Users/saish/Downloads/Projects/NLP Project/MasterDictionary"

# load all stop wors from the stopwords directory and store in the set variable
stop_words = set()
for files in os.listdir(stopwords_dir):
  with open(os.path.join(stopwords_dir,files),'r',encoding='ISO-8859-1') as f:
    stop_words.update(set(f.read().splitlines()))
print("Stop Words :")
print(stop_words)
# load all text files  from the  directory and store in a list(docs)
docs = []
for text_file in os.listdir(text_dir):
  with open(os.path.join(text_dir,text_file),'r',encoding='utf-8') as f:
    text = f.read()
#tokenize the given text file
    words = word_tokenize(text)
# remove the stop words from the tokens
    filtered_text = [word for word in words if word.lower() not in stop_words]
# add each filtered tokens of each file into a list
    docs.append(filtered_text)



# store positive, Negative words from the directory
pos=set()
neg=set()

for files in os.listdir(sentment_dir):
  if files =='positive-words.txt':
    with open(os.path.join(sentment_dir,files),'r',encoding='ISO-8859-1') as f:
      pos.update(f.read().splitlines())
  else:
    with open(os.path.join(sentment_dir,files),'r',encoding='ISO-8859-1') as f:
      neg.update(f.read().splitlines())

# now collect the positive  and negative words from each file
# calculate the scores from the positive and negative words 
positive_words = []
Negative_words =[]
positive_score = []
negative_score = []
polarity_score = []
subjectivity_score = []

#iterate through the list of docs
for i in range(len(docs)):
  positive_words.append([word for word in docs[i] if word.lower() in pos])
  Negative_words.append([word for word in docs[i] if word.lower() in neg])
  positive_score.append(len(positive_words[i]))
  negative_score.append(len(Negative_words[i]))
  polarity_score.append((positive_score[i] - negative_score[i]) / ((positive_score[i] + negative_score[i]) + 0.000001))
  subjectivity_score.append((positive_score[i] + negative_score[i]) / ((len(docs[i])) + 0.000001))
# Out:
# Stop Words :
# {'GAY', 'LINDER', 'VICKERY', 'HOM', 'MARSHA', 'HALINA', 'BUCKLEY', 'VELAZQUEZ', 'SILAS', 'IZZO', 'KAMINSKI', 'MCDADE', 'have', 'RUBIN', 'BURR', 'RUGGIERO', 'SEPULVEDA', 'ASHLYN', 'CUELLAR', 'BOLIVIANO  | Bolivia ', 'HAY', 'RUBY', 'MEZA', 'BECKLEY', 'RONNI', 'DELRIO', 'here', 'RAPER', 'DARRICK', 'PERRI', 'HELGA', 'BARAN', 'BOUTTE', 'PAINTER', 'LAURENA', 'FRAN', 'ISOBEL', 'BELK', 'PIZARRO', 'DOOLEY', 'BEALS', 'MINH', 'SALLY', 'NOBUKO', 'WORTHEN', 'GRIMM', 'CARBONE', 'HARROD', 'HORTENSIA', 'MCCALLISTER', 'DAINE', 'DANIELE', 'CASSI', 'THAMES', 'CHIU', 'JERNIGAN', 'CLARINE', 'PERRON', 'HAZARD', 'SPERRY', 'XIOMARA', 'HERSELF', 'DONITA', 'PROVIDENCIA', 'whence', 'REINA', 'WENDEL', 'DARON', 'ALENA', 'JEANIE', 'AVALOS', 'ADRIANNE', 'RIVA', 'FORD', 'ART', 'SHANI', 'HIXON', 'SUISSE', 'BYERLY', 'FIVE', 'CARNEY', 'MUSICK', 'LIVINGSTON', 'JETTIE', 'TOBIN', 'HARP', 'ANDY', 'OCONNELL', 'PETRIE', 'HILDA', 'comes', 'SENAIDA', 'off', 'MADALENE', 'TASHIA', 'ODIS', 'CLARK', 'TIANA', 'MELIDA', 'XIV', 'ALLEY', 'KLUG', 'OLIVERA', 'SPAULDING', 'ROCKWELL', 'BRIAN', 'ELMER', 'MILLET', 'LAKISHA', 'CONROY', 'CARRERA', 'SYKES', 'WALDROP', 'RAQUEL', 'DEMARCO', 'ESKEW', 'CHANCELLOR', 'CORDER', 'DERRICK', 'GREAVES', 'PERSINGER', 'LUANA', 'ESTA', 'COONEY', 'DAPHNE', 'SHELA', 'DIRHAM  | Morocco ', 'beyond', 'HEARN', 'LAVERN', 'GEORGETTA', 'DEWEY', 'BYERS', 'GOSNELL', 'LIGGINS', 'during', 'MCLAUGHLIN', 'JENNA', 'LETA', 'LASHAWNA', 'LASHAUNDA', 'RANDAL', 'CHARLOTTE', 'LAMONTAGNE', 'VIVA', 'ARVILLA', 'MULLIS', 'KASANDRA', 'TARDIFF', 'CARMA', "what's", 'ROSS', 'TRUDI', 'HILARY', 'SAMPSON', 'NARANJO', 'FLORIN | Aruba ', 'DORE', 'ELISABETH', 'LELA', 'EVIE', 'TABATHA', 'HODGSON', 'MASON', 'JUSTINE', 'LUANNE', 'CONAWAY', 'KEVA', 'LEXIE', 'DEMERS', 'ALYSON', 'THIBEAULT', 'FIDEL', 'BOUTIN', 'TEAL', 'CUC', 'RAUL', 'JOHNETTA', 'LAEL', 'VICKI', 'NUEVO SOL | Peru ', 'WALL', 'IRVIN', 'PRESCOTT', 'RAGAN', 'among', 'MARYETTA', 'MONK', 'SALTER', 'GERALDO', 'BRIGITTE', 'KIGER', 'HUNT', 'RICHARDS', 'BEECHER', 'RAINWATER', 'PRICHARD', 'ERMELINDA', "a's", 'LAWTON', 'SHUMAN', 'ESTEVEZ', 'SHAWNDA', 'PULLEY', 'ROMEO', 'PATTERSON', 'ERNST', 'STRUNK', 'ELAYNE', 'MARR', 'YAN', 'JEANA', 'SPENCE', 'DOROTHY', 'THALIA', 'MINCEY', 'none', 'VELIZ', 'MEARS', 'ISRAEL', 'JORGE', 'LAVELLE', 'SPIEGEL', 'DETROIT', 'DOLLY', 'COLMAN', 'SHELLY', 'SCHUMANN', 'MONROE', 'JANE', 'ALMA', 'GARRIS', 'MILAN', 'ELEANOR', 'PAMULA', 'PHEBE', 'LAFRANCE', 'POPE', 'ARMANDINA', 'BURKHOLDER', 'COLETTE', 'ESTHER', 'VERDUGO', 'CHANELL', 'AGRIPINA', 'FAUSTINA', 'PENDER', 'DONOVAN', 'LIM', 'MYRTLE', 'SEAY', 'LANGSTON', 'BRITTNY', 'BERGSTROM', 'LAURE', 'REAL', 'BUGGS', 'TENNANT', 'MESA', 'DEANDREA', 'AGUILERA', 'CINDIE', 'BENEDICT', 'MARINE', 'BEE', 'LINTON', 'ALETHIA', 'NORWOOD', 'RIDDICK', 'TEREASA', 'KATHERN', 'GOODRICH', 'PEACHEY', 'TRAMMELL', 'SONIA', 'MALONEY', 'NAOMI', 'NICHOLLE', 'DARCEY', 'TOLLEY', 'ALESIA', 'GIST', 'FARINA', 'HOLLAR', 'MESSICK', 'ERICSON', 'TOMMIE', 'HOFER', 'GINN', 'MELONIE', 'BENN', 'HAROLD', 'CORENE', 'ENDICOTT', 'DUNLAP', 'SAVAGE', 'CASTLEBERRY', 'CLINT', 'SHUPE', 'PAGE', 'MARISA', 'VANHOUTEN', 'SHAUNDA', 'HARDING', 'NATHANIEL', 'PEACE', 'OATES', 'DEAN', 'WHITING', 'THAXTON', 'NANNETTE', 'MIMS', 'BLANKS', 'SHANK', 'FERRANTE', 'KUYKENDALL', 'GETZ', 'PEELE', 'HOFFER', 'ALBRITTON', 'FOURTH', 'COURSON', 'serious', 'TYRON', 'CÓRDOBA  | Nicaragua ', 'STAHL', 'HORN', 'LILA', 'thorough', 'KNOX', 'LORIE', 'MACOMBER', 'LAHOMA', 'RUFINA', 'ARCHIBALD', 'GOOLSBY', 'LANCE', 'WARRINGTON', 'THELMA', 'KACI', 'MERCEDES', 'SEARS', 'CAUTHEN', 'WATTS', 'TAMEKIA', 'IRMGARD', 'PATRICIA', 'KWACHA | Zambia ', 'BURDINE', 'CHURCHILL', 'HENDERSON', 'LEVERETT', 'LUNA', 'UTTER', 'STOKER', 'ROSEMARY', 'LEONORA', 'JARROD', 'HARLEY', 'SCHUTZ', 'SAVANNA', 'YING', 'TEGAN', 'POWERS', 'MUNOZ', 'OSTRANDER', 'MARGIE', 'LAM', 'ROBT', 'BRIANNE', 'me', 'BUFFINGTON', 'SAAD', 'WATERS', 'EUGENIA', 'JI', 'HORNBACK', 'WHIPPLE', 'TYRA', 'AURELIO', 'NEVADA', 'FRIAS', 'TIMOTHY', 'GREINER', 'BILLIOT', 'WANETA', "where's", 'BARRON', 'DORAN', 'D ...

# %%
# Now you can create a set of English stopwords
stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\saish\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Average Sentence Length = the number of words / the number of sentences
# Percentage of Complex words = the number of complex words / the number of words 
# Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)

avg_sentence_length = []
Percentage_of_Complex_words  =  []
Fog_Index = []
complex_word_count =  []
avg_syllable_word_count =[]


def measure(file):
  with open(os.path.join(text_dir, file),'r', encoding='utf-8') as f:
    text = f.read()
# remove punctuations 
    text = re.sub(r'[^\w\s.]','',text)
# split the given text file into sentences
    sentences = text.split('.')
# total number of sentences in a file
    num_sentences = len(sentences)
# total words in the file
    words = [word  for word in text.split() if word.lower() not in stopwords ]
    num_words = len(words)
 
# complex words having syllable count is greater than 2
# Complex words are words in the text that contain more than two syllables.
    complex_words = []
    for word in words:
      vowels = 'aeiou'
      syllable_count_word = sum( 1 for letter in word if letter.lower() in vowels)
      if syllable_count_word > 2:
        complex_words.append(word)

# Syllable Count Per Word
# We count the number of Syllables in each word of the text by counting the vowels present in each word.
#  We also handle some exceptions like words ending with "es","ed" by not counting them as a syllable.
    syllable_count = 0
    syllable_words =[]
    for word in words:
      if word.endswith('es'):
        word = word[:-2]
      elif word.endswith('ed'):
        word = word[:-2]
      vowels = 'aeiou'
      syllable_count_word = sum( 1 for letter in word if letter.lower() in vowels)
      if syllable_count_word >= 1:
        syllable_words.append(word)
        syllable_count += syllable_count_word


    avg_sentence_len = num_words / num_sentences
    avg_syllable_word_count = syllable_count / (len(syllable_words)+0.000001)
    Percent_Complex_words  =  len(complex_words) / (num_words+0.000001)
    Fog_Index = 0.4 * (avg_sentence_len + Percent_Complex_words)

    return avg_sentence_len, Percent_Complex_words, Fog_Index, len(complex_words),avg_syllable_word_count

# iterate through each file or doc
for file in os.listdir(text_dir):
  x,y,z,a,b = measure(file)
  avg_sentence_length.append(x)
  Percentage_of_Complex_words.append(y)
  Fog_Index.append(z)
  complex_word_count.append(a)
  avg_syllable_word_count.append(b)

# %%
# Word Count and Average Word Length Sum of the total number of characters in each word/Total number of words
# We count the total cleaned words present in the text by 
# removing the stop words (using stopwords class of nltk package).
# removing any punctuations like ? ! , . from the word before counting.

def cleaned_words(file):
  with open(os.path.join(text_dir,file), 'r',encoding='utf-8') as f:
    text = f.read()
    text = re.sub(r'[^\w\s]', '' , text)
    words = [word  for word in text.split() if word.lower() not in stopwords]
    length = sum(len(word) for word in words)
    average_word_length = length / (len(words)+0.000001)
  return len(words),average_word_length

word_count = []
average_word_length = []
for file in os.listdir(text_dir):
  x, y = cleaned_words(file)
  word_count.append(x)
  average_word_length.append(y)


# To calculate Personal Pronouns mentioned in the text, we use regex to find 
# the counts of the words - “I,” “we,” “my,” “ours,” and “us”. Special care is taken
#  so that the country name US is not included in the list.
def count_personal_pronouns(file):
  with open(os.path.join(text_dir,file), 'r',encoding='utf-8') as f:
    text = f.read()
    personal_pronouns = ["I", "we", "my", "ours", "us"]
    count = 0
    for pronoun in personal_pronouns:
      count += len(re.findall(r"\b" + pronoun + r"\b", text)) # \b is used to match word boundaries
  return count

pp_count = []
for file in os.listdir(text_dir):
  x = count_personal_pronouns(file)
  pp_count.append(x)

# %%
output_df = pd.read_excel('Output Data Structure.xlsx')
print(len(positive_score))
# URL_ID 44 ,57, 144 does not exists i,e. page does not exist, throughs 404 error
# so we are going to drop these rows from the table
output_df.drop([57-37,144-37], axis = 0, inplace=True)

# These are the required parameters 
variables = [positive_score,
            negative_score,
            polarity_score,
            subjectivity_score,
            avg_sentence_length,
            Percentage_of_Complex_words,
            Fog_Index,
            avg_sentence_length,
            complex_word_count,
            word_count,
            avg_syllable_word_count,
            pp_count,
            average_word_length]

# write the values to the dataframe
for i, var in enumerate(variables):
  output_df.iloc[:,i+2] = var

#now save the dataframe to the disk
output_df.to_csv('Output_Data.csv')
# Out:
# 112
# C:\Users\saish\AppData\Local\Temp\ipykernel_19336\996107706.py:24: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   output_df.iloc[:,i+2] = var
